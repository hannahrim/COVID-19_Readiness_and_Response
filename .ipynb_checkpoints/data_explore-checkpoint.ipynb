# %%
# import dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from flask import Flask
from flask_sqlalchemy import SQLAlchemy
from os import environ
from sqlalchemy import create_engine

# %%
# Create flask to connect database 
app = Flask(__name__)
app.config['SQLALCHEMY_TRACK_MODIFICATIONS'] = True
engine = create_engine("postgresql://June:Covid19*@covid19-readiness.cwom5umbekrh.us-west-1.rds.amazonaws.com/SPA_data")
# Create dataframe from PostgreSQL
df = pd.read_sql_table('combined_full_data',con=engine)

# %%
df.head()
# Out:
#    facil country region  zone  region_code region_name     latnum    longnum  \
# 0  11117     BAN      6  None            6     Rangpur  25.412535  89.052128
# 1  11600     BAN      8  None            8  Mymensingh  25.145923  89.935113
# 2  11599     BAN      8  None            8  Mymensingh  25.015608  90.014368
# 3  11598     BAN      8  None            8  Mymensingh  24.716940  90.953117
# 4  11597     BAN      8  None            8  Mymensingh  24.739533  90.527265
#
#    factype  mga  ...  tbservice  hivcare  meetings  quality  inpatient  \
# 0        8    1  ...        0.0      NaN       NaN      0.0        0.0
# 1       12    3  ...        0.0      NaN       NaN      0.0        0.0
# 2       12    3  ...        0.0      NaN       NaN      1.0        1.0
# 3       12    3  ...        0.0      NaN       NaN      0.0        0.0
# 4       12    3  ...        1.0      NaN       NaN      0.0        0.0
#
#    numberbeds  total_full  outpatients  cumulative_cases  cumulative_deaths
# 0         NaN         3.0          NaN            377073               5500
# 1         NaN        22.0          NaN            377073               5500
# 2         1.0        12.0        198.0            377073               5500
# 3         NaN         6.0          NaN            377073               5500
# 4         NaN         9.0          NaN            377073               5500
#
# [5 rows x 32 columns]

# %%
# Check the datatypes
df.dtypes
# Out:
# facil                  int64
# country               object
# region                object
# zone                  object
# region_code            int64
# region_name           object
# latnum               float64
# longnum              float64
# factype                int64
# mga                    int64
# ftype                  int64
# factype2               int64
# ownership              int64
# water_source         float64
# soapwater            float64
# st_precautions       float64
# disinfectant         float64
# latexgloves          float64
# medicalmasks         float64
# gowns                float64
# eye_protect          float64
# preparedness         float64
# tbservice            float64
# hivcare              float64
# meetings             float64
# quality              float64
# inpatient            float64
# numberbeds           float64
# total_full           float64
# outpatients          float64
# cumulative_cases       int64
# cumulative_deaths      int64
# dtype: object

# %%
# Count NAs for each columns
[[column,df[column].isnull().sum()] for column in df.columns]
# Out:
# [['facil', 0],
#  ['country', 0],
#  ['region', 0],
#  ['zone', 4045],
#  ['region_code', 0],
#  ['region_name', 0],
#  ['latnum', 213],
#  ['longnum', 213],
#  ['factype', 0],
#  ['mga', 0],
#  ['ftype', 0],
#  ['factype2', 0],
#  ['ownership', 0],
#  ['water_source', 311],
#  ['soapwater', 150],
#  ['st_precautions', 150],
#  ['disinfectant', 18],
#  ['latexgloves', 18],
#  ['medicalmasks', 18],
#  ['gowns', 18],
#  ['eye_protect', 18],
#  ['preparedness', 18],
#  ['tbservice', 150],
#  ['hivcare', 1771],
#  ['meetings', 1674],
#  ['quality', 150],
#  ['inpatient', 150],
#  ['numberbeds', 1751],
#  ['total_full', 247],
#  ['outpatients', 2724],
#  ['cumulative_cases', 0],
#  ['cumulative_deaths', 0]]

# %%
# Drop columns with more than 10% of na
df.drop('zone', axis=1, inplace=True)
df.drop('outpatients', axis=1, inplace=True)
df.drop('hivcare', axis=1, inplace=True)
df.drop('meetings', axis=1, inplace=True)

# %%
# Drop na for infection control indicators
df['water_source'] = df['water_source'].dropna()
df['soapwater'] = df['soapwater'].dropna()
df['st_precautions'] = df['st_precautions'].dropna()
df['disinfectant'] = df['disinfectant'].dropna()
df['latexgloves'] = df['latexgloves'].dropna()
df['medicalmasks'] = df['medicalmasks'].dropna()
df['gowns'] = df['gowns'].dropna()
df['eye_protect'] = df['eye_protect'].dropna()

# %%
df.describe()
# Out:
#               facil  region_code       latnum      longnum      factype  \
# count   4529.000000  4529.000000  4316.000000  4316.000000  4529.000000
# mean   15296.932877    19.735262    13.775843    20.145659     4.826893
# std    13893.942598    26.889799    11.375674    63.026978     2.279125
# min        1.000000     1.000000   -12.742820   -74.454312     1.000000
# 25%     1133.000000     2.000000     1.916200   -17.334832     3.000000
# 50%    10853.000000     6.000000    18.551235    23.309045     5.000000
# 75%    30385.000000    32.000000    22.965235    89.706431     6.000000
# max    40484.000000    93.000000    26.587388    92.429650    12.000000
#
#                mga        ftype     factype2    ownership  water_source  ...  \
# count  4529.000000  4529.000000  4529.000000  4529.000000   4218.000000  ...
# mean      1.791786     1.758887     1.773902     1.349304      0.630156  ...
# std       1.161121     0.727535     0.418350     0.476803      0.482819  ...
# min       1.000000     1.000000     1.000000     1.000000      0.000000  ...
# 25%       1.000000     1.000000     2.000000     1.000000      0.000000  ...
# 50%       1.000000     2.000000     2.000000     1.000000      1.000000  ...
# 75%       3.000000     2.000000     2.000000     2.000000      1.000000  ...
# max       9.000000     9.000000     2.000000     2.000000      1.000000  ...
#
#              gowns  eye_protect  preparedness    tbservice      quality  \
# count  4511.000000  4511.000000   4511.000000  4379.000000  4379.000000
# mean      0.630016     0.083795      0.432463     0.632336     0.451701
# std       0.482854     0.277111      0.218342     0.482224     0.497719
# min       0.000000     0.000000      0.000000     0.000000     0.000000
# 25%       0.000000     0.000000      0.273000     0.000000     0.000000
# 50%       1.000000     0.000000      0.455000     1.000000     0.000000
# 75%       1.000000     0.000000      0.545000     1.000000     1.000000
# max       1.000000     1.000000      1.000000     1.000000     1.000000
#
#          inpatient   numberbeds   total_full  cumulative_cases  \
# count  4379.000000  2778.000000  4282.000000       4529.000000
# mean      0.412423    35.444204    24.924568     138454.159417
# std       0.492327    95.061828    73.792766     176405.045523
# min       0.000000     0.000000     0.000000       5118.000000
# 25%       0.000000     3.000000     3.000000       5118.000000
# 50%       0.000000    10.000000     8.000000       8860.000000
# 75%       1.000000    38.000000    24.750000     377073.000000
# max       1.000000   998.000000  2573.000000     377073.000000
#
#        cumulative_deaths
# count        4529.000000
# mean         2057.001987
# std          2545.961612
# min            90.000000
# 25%            90.000000
# 50%           230.000000
# 75%          5500.000000
# max          5500.000000
#
# [8 rows x 25 columns]

# %%
df
# Out:
#       facil country region  region_code region_name     latnum    longnum  \
# 0     11117     BAN      6            6     Rangpur  25.412535  89.052128
# 1     11600     BAN      8            8  Mymensingh  25.145923  89.935113
# 2     11599     BAN      8            8  Mymensingh  25.015608  90.014368
# 3     11598     BAN      8            8  Mymensingh  24.716940  90.953117
# 4     11597     BAN      8            8  Mymensingh  24.739533  90.527265
# ...     ...     ...    ...          ...         ...        ...        ...
# 4524  40005     SEN      1            1       Dakar  14.702790 -17.461980
# 4525  40004     SEN      1            1       Dakar  14.692600 -17.467000
# 4526  40003     SEN      1            1       Dakar  14.722490 -17.451410
# 4527  40002     SEN      1            1       Dakar  14.694460 -17.464080
# 4528  40001     SEN      1            1       Dakar  14.692960 -17.464650
#
#       factype  mga  ftype  ...  gowns  eye_protect  preparedness  tbservice  \
# 0           8    1      2  ...    0.0          0.0         0.273        0.0
# 1          12    3      2  ...    1.0          1.0         1.000        0.0
# 2          12    3      1  ...    1.0          1.0         1.000        0.0
# 3          12    3      2  ...    1.0          1.0         1.000        0.0
# 4          12    3      2  ...    0.0          0.0         0.727        1.0
# ...       ...  ...    ...  ...    ...          ...           ...        ...
# 4524        1    3      1  ...    1.0          0.0         0.636        0.0
# 4525        1    3      1  ...    1.0          0.0         0.636        NaN
# 4526        1    3      1  ...    1.0          0.0         0.636        1.0
# 4527        1    3      1  ...    0.0          0.0         0.455        1.0
# 4528        1    1      1  ...    1.0          0.0         0.727        1.0
#
#       quality  inpatient  numberbeds  total_full  cumulative_cases  \
# 0         0.0        0.0         NaN         3.0            377073
# 1         0.0        0.0         NaN        22.0            377073
# 2         1.0        1.0         1.0        12.0            377073
# 3         0.0        0.0         NaN         6.0            377073
# 4         0.0        0.0         NaN         9.0            377073
# ...       ...        ...         ...         ...               ...
# 4524      0.0        0.0         NaN         3.0             15213
# 4525      NaN        NaN         NaN         NaN             15213
# 4526      0.0        1.0        19.0        36.0             15213
# 4527      0.0        1.0        12.0        15.0             15213
# 4528      1.0        1.0         0.0       168.0             15213
#
#       cumulative_deaths
# 0                  5500
# 1                  5500
# 2                  5500
# 3                  5500
# 4                  5500
# ...                 ...
# 4524                313
# 4525                313
# 4526                313
# 4527                313
# 4528                313
#
# [4529 rows x 28 columns]

# %%
# Calculate preparedness as mean of infection control indicators
df['preparedness2'] = df[['soapwater','disinfectant','medicalmasks','eye_protect']].mean(axis=1)

# %%
# create binary output of preparedness
def bol(x): 
    if x >= 1:
        value = 1 
    else: 
        value = 0 
    return(value) 
df['prep2'] = df['preparedness2'].apply(lambda row: bol(row) )

# %%
df['prep2'].value_counts()
# Out:
# 0    4260
# 1     269
# Name: prep2, dtype: int64

# %%
# Count sample size for each country
df['country'].value_counts()
# Out:
# BAN    1600
# DRC    1412
# HAI    1033
# SEN     484
# Name: country, dtype: int64

# %%
# Create seperate dataframes for each country
senegal = df.loc[lambda df: df['country'] == 'SEN']
bangladesh = df.loc[lambda df: df['country'] == 'BAN']
haiti = df.loc[lambda df: df['country'] == 'HAI']
congo = df.loc[lambda df: df['country'] == 'DRC']

# %%
# Create preparedness tables for each country 
SEN = senegal['preparedness'].dropna()
BAN = bangladesh['preparedness'].dropna()
HAI = haiti['preparedness'].dropna()
DRC = congo['preparedness'].dropna()

# %%
# Box plot for preparedness by Country 
x_labels = ["SEN", "BAN","HAI","DRC"]
preparedness_data = [SEN, BAN, HAI, DRC]
fig, ax = plt.subplots(figsize=(10, 6))
ax.boxplot(preparedness_data, labels=x_labels)
ax.set_title('Preparedness by Country')
ax.set_ylabel('Preparedness for infection control')
ax.grid()
plt.show()

# %%
df.dtypes
# Out:
# facil                  int64
# country               object
# region                object
# region_code            int64
# region_name           object
# latnum               float64
# longnum              float64
# factype                int64
# mga                    int64
# ftype                  int64
# factype2               int64
# ownership              int64
# water_source         float64
# soapwater            float64
# st_precautions       float64
# disinfectant         float64
# latexgloves          float64
# medicalmasks         float64
# gowns                float64
# eye_protect          float64
# preparedness         float64
# tbservice            float64
# quality              float64
# inpatient            float64
# numberbeds           float64
# total_full           float64
# cumulative_cases       int64
# cumulative_deaths      int64
# preparedness2        float64
# prep2                  int64
# dtype: object

# %%
df.head(15)
# Out:
#     facil country region  region_code region_name     latnum    longnum  \
# 0   11117     BAN      6            6     Rangpur  25.412535  89.052128
# 1   11600     BAN      8            8  Mymensingh  25.145923  89.935113
# 2   11599     BAN      8            8  Mymensingh  25.015608  90.014368
# 3   11598     BAN      8            8  Mymensingh  24.716940  90.953117
# 4   11597     BAN      8            8  Mymensingh  24.739533  90.527265
# 5   11596     BAN      8            8  Mymensingh  24.894568  89.708767
# 6   11595     BAN      8            8  Mymensingh  25.194067  89.868093
# 7   11594     BAN      7            7      Sylhet  24.818377  91.750745
# 8   11593     BAN      7            7      Sylhet  24.896652  91.900082
# 9   11592     BAN      7            7      Sylhet  25.073562  92.112103
# 10  11591     BAN      7            7      Sylhet  24.725532  91.756097
# 11  11590     BAN      7            7      Sylhet   0.000000   0.000000
# 12  11589     BAN      7            7      Sylhet  24.389328  91.753662
# 13  11588     BAN      7            7      Sylhet  24.648010  91.590883
# 14  11587     BAN      6            6     Rangpur  25.335587  89.274513
#
#     factype  mga  ftype  ...  preparedness  tbservice  quality  inpatient  \
# 0         8    1      2  ...         0.273        0.0      0.0        0.0
# 1        12    3      2  ...         1.000        0.0      0.0        0.0
# 2        12    3      1  ...         1.000        0.0      1.0        1.0
# 3        12    3      2  ...         1.000        0.0      0.0        0.0
# 4        12    3      2  ...         0.727        1.0      0.0        0.0
# 5        12    3      2  ...         0.727        0.0      1.0        0.0
# 6        12    3      1  ...         0.727        0.0      0.0        0.0
# 7        12    3      2  ...         0.636        0.0      1.0        0.0
# 8        12    3      1  ...         0.909        0.0      1.0        0.0
# 9        12    3      2  ...         0.727        0.0      0.0        0.0
# 10       12    3      2  ...         0.636        0.0      1.0        0.0
# 11       12    3      2  ...         0.909        0.0      1.0        0.0
# 12       12    3      2  ...         0.727        0.0      1.0        0.0
# 13       12    3      2  ...         0.636        1.0      0.0        0.0
# 14       12    3      2  ...         0.909        0.0      1.0        0.0
#
#     numberbeds  total_full  cumulative_cases  cumulative_deaths  \
# 0          NaN         3.0            377073               5500
# 1          NaN        22.0            377073               5500
# 2          1.0        12.0            377073               5500
# 3          NaN         6.0            377073               5500
# 4          NaN         9.0            377073               5500
# 5          0.0        14.0            377073               5500
# 6          1.0         8.0            377073               5500
# 7          NaN         6.0            377073               5500
# 8          NaN         8.0            377073               5500
# 9          NaN         8.0            377073               5500
# 10         NaN         7.0            377073               5500
# 11         NaN         9.0            377073               5500
# 12         NaN         9.0            377073               5500
# 13         NaN        11.0            377073               5500
# 14         0.0        13.0            377073               5500
#
#     preparedness2  prep2
# 0            0.25      0
# 1            1.00      1
# 2            1.00      1
# 3            1.00      1
# 4            0.50      0
# 5            0.50      0
# 6            1.00      1
# 7            0.75      0
# 8            1.00      1
# 9            0.75      0
# 10           0.75      0
# 11           1.00      1
# 12           0.75      0
# 13           1.00      1
# 14           1.00      1
#
# [15 rows x 30 columns]

# %%
# Export cleaned data into sql 
df.to_sql(name='combined_data_cleaned', con=engine, if_exists='replace')

# %%
# Calculate cumulative cases and cumulative deaths for each country
cumulative_cases = df.groupby(["country"]).mean()["cumulative_cases"]
print(cumulative_cases)
cumulative_deaths = df.groupby(["country"]).mean()["cumulative_deaths"]
print(cumulative_deaths)
# Out:
# country
# BAN    377073.0
# DRC      5118.0
# HAI      8860.0
# SEN     15213.0
# Name: cumulative_cases, dtype: float64
# country
# BAN    5500.0
# DRC      90.0
# HAI     230.0
# SEN     313.0
# Name: cumulative_deaths, dtype: float64

# %%
cumulative_cases.plot(kind='bar')

# %%
cumulative_deaths.plot(kind='bar')

# %%
# Create covid-19 cases dataframe
covid_data={"country" :['BAN','DRC','HAI','SEN'],
          'cumulative_cases': df.groupby(["country"]).mean()["cumulative_cases"],
          'cumulative_deaths':df.groupby(["country"]).mean()["cumulative_deaths"],
          'population':[161376708,101780263,11439646,15854323]
         }
covid_df = pd.DataFrame(covid_data, columns = ['country', 'cumulative_cases','cumulative_deaths','population'])

# %%
covid_df['cases_per_100K']=covid_df['cumulative_cases']/covid_df['population']*100000
covid_df['deaths_per_100k']=covid_df['cumulative_deaths']/covid_df['population']*100000

# %%
# Create bar chart of cumulative cases for countries
covid_df['cases_per_100K'].plot(kind='bar')

# %%
# Create bar chart of cumulative deaths for countries
covid_df['cases_per_100K'].plot(kind='bar')

# %%
covid_df
# Out:
#         country  cumulative_cases  cumulative_deaths  population  \
# country
# BAN         BAN          377073.0             5500.0   161376708
# DRC         DRC            5118.0               90.0   101780263
# HAI         HAI            8860.0              230.0    11439646
# SEN         SEN           15213.0              313.0    15854323
#
#          cases_per_100K  deaths_per_100k
# country
# BAN          233.660114         3.408175
# DRC            5.028480         0.088426
# HAI           77.449949         2.010552
# SEN           95.954901         1.974225

# %%
# Reset country to index 
covid_df.set_index(covid_df['country'],inplace=True)
covid_df.drop('country', axis=1, inplace=True)

# %%
# Upload covid-19 dataframe to SQL
covid_df.to_sql(name='covid_data_calculated', con=engine, if_exists='replace')
