# %%
# import dependencies
import numpy as np
import pandas as pd
import scipy as scy 
from path import Path
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# import combined data 
data = Path('Resource/Combined_data.csv')
df = pd.read_csv(data, usecols = ['FACIL','Country','REGION_code','REGION_name','Zone','FACTYPE','MGA',
                                  'FTYPE','Factype2','ownership',
                                  'water_source','soapwater','st_precautions','preparedness','prep2',
                                  'TBservice','HIVcare','meetings','quality',
                                  'inpatient','numberbeds','total_full','outpatients',
                                  'LATNUM','LONGNUM'])

# %%
df
# Out:
#       FACIL Country  REGION_code REGION_name  Zone  FACTYPE  MGA  FTYPE  \
# 0     40001     SEN            1       Dakar   2.0        1    1      1
# 1     40002     SEN            1       Dakar   2.0        1    3      1
# 2     40003     SEN            1       Dakar   2.0        1    3      1
# 3     40004     SEN            1       Dakar   2.0        1    3      1
# 4     40005     SEN            1       Dakar   2.0        1    3      1
# ...     ...     ...          ...         ...   ...      ...  ...    ...
# 4524  31029     HAI            1       Ouest   NaN        6    2      2
# 4525  31030     HAI            2     Sud-Est   NaN        7    2      2
# 4526  31031     HAI            1       Ouest   NaN        6    3      2
# 4527  31032     HAI            6      Centre   NaN        6    3      2
# 4528  31033     HAI            2     Sud-Est   NaN        5    3      2
#
#       Factype2  ownership  ...  TBservice  HIVcare  meetings  quality  \
# 0            1          1  ...        1.0      1.0       0.0      1.0
# 1            1          2  ...        1.0      0.0       1.0      0.0
# 2            1          2  ...        1.0      0.0       1.0      0.0
# 3            1          2  ...        NaN      NaN       NaN      NaN
# 4            1          2  ...        0.0      0.0       0.0      0.0
# ...        ...        ...  ...        ...      ...       ...      ...
# 4524         2          2  ...        0.0      0.0       1.0      0.0
# 4525         2          2  ...        0.0      0.0       1.0      0.0
# 4526         2          2  ...        1.0      0.0       1.0      0.0
# 4527         2          2  ...        1.0      0.0       1.0      0.0
# 4528         2          2  ...        1.0      0.0       1.0      0.0
#
#       inpatient  numberbeds  total_full  outpatients     LATNUM    LONGNUM
# 0           1.0         0.0       168.0        438.0  14.692960 -17.464650
# 1           1.0        12.0        15.0         12.0  14.694460 -17.464080
# 2           1.0        19.0        36.0         48.0  14.722490 -17.451410
# 3           NaN         NaN         NaN          NaN  14.692600 -17.467000
# 4           0.0         NaN         3.0          NaN  14.702790 -17.461980
# ...         ...         ...         ...          ...        ...        ...
# 4524        0.0         NaN         6.0          NaN  18.443573 -72.635510
# 4525        0.0         NaN         2.0          NaN  18.248150 -72.535530
# 4526        0.0         NaN         6.0          NaN  18.839828 -72.520555
# 4527        0.0         NaN         5.0          NaN  18.753397 -72.147913
# 4528        0.0         3.0        14.0          NaN  18.256012 -72.610743
#
# [4529 rows x 25 columns]

# %%
# Check the datatypes
df.dtypes
# Out:
# FACIL               int64
# Country            object
# REGION_code         int64
# REGION_name        object
# Zone              float64
# FACTYPE             int64
# MGA                 int64
# FTYPE               int64
# Factype2            int64
# ownership           int64
# water_source      float64
# soapwater         float64
# st_precautions    float64
# preparedness      float64
# prep2             float64
# TBservice         float64
# HIVcare           float64
# meetings          float64
# quality           float64
# inpatient         float64
# numberbeds        float64
# total_full        float64
# outpatients       float64
# LATNUM            float64
# LONGNUM           float64
# dtype: object

# %%
# Count NAs for each columns
[[column,df[column].isnull().sum()] for column in df.columns]
# Out:
# [['FACIL', 0],
#  ['Country', 0],
#  ['REGION_code', 0],
#  ['REGION_name', 0],
#  ['Zone', 4045],
#  ['FACTYPE', 0],
#  ['MGA', 0],
#  ['FTYPE', 0],
#  ['Factype2', 0],
#  ['ownership', 0],
#  ['water_source', 311],
#  ['soapwater', 150],
#  ['st_precautions', 150],
#  ['preparedness', 1262],
#  ['prep2', 207],
#  ['TBservice', 150],
#  ['HIVcare', 1771],
#  ['meetings', 1674],
#  ['quality', 150],
#  ['inpatient', 150],
#  ['numberbeds', 1751],
#  ['total_full', 247],
#  ['outpatients', 2724],
#  ['LATNUM', 213],
#  ['LONGNUM', 213]]

# %%
# Drop columns with more than 50% of na
df.drop('Zone', axis=1, inplace=True)
df.drop('outpatients', axis=1, inplace=True)

# %%
# Drop na for infection control indicators
df['water_source'].dropna()
df['soapwater'].dropna()
df['st_precautions'].dropna()
# Out:
# 0       0.0
# 1       0.0
# 2       0.0
# 4       0.0
# 8       0.0
#        ...
# 4524    0.0
# 4525    1.0
# 4526    0.0
# 4527    0.0
# 4528    0.0
# Name: st_precautions, Length: 4379, dtype: float64

# %%
df.describe()
# Out:
#               FACIL  REGION_code      FACTYPE          MGA        FTYPE  \
# count   4529.000000  4529.000000  4529.000000  4529.000000  4529.000000
# mean   15296.932877    19.735262     4.826893     1.791786     1.758887
# std    13893.942598    26.889799     2.279125     1.161121     0.727535
# min        1.000000     1.000000     1.000000     1.000000     1.000000
# 25%     1133.000000     2.000000     3.000000     1.000000     1.000000
# 50%    10853.000000     6.000000     5.000000     1.000000     2.000000
# 75%    30385.000000    32.000000     6.000000     3.000000     2.000000
# max    40484.000000    93.000000    12.000000     9.000000     9.000000
#
#           Factype2    ownership  water_source    soapwater  st_precautions  \
# count  4529.000000  4529.000000   4218.000000  4379.000000     4379.000000
# mean      1.773902     1.349304      0.630156     0.760676        0.241608
# std       0.418350     0.476803      0.482819     0.426720        0.428107
# min       1.000000     1.000000      0.000000     0.000000        0.000000
# 25%       2.000000     1.000000      0.000000     1.000000        0.000000
# 50%       2.000000     1.000000      1.000000     1.000000        0.000000
# 75%       2.000000     2.000000      1.000000     1.000000        0.000000
# max       2.000000     2.000000      1.000000     1.000000        1.000000
#
#        ...        prep2    TBservice      HIVcare     meetings      quality  \
# count  ...  4322.000000  4379.000000  2758.000000  2855.000000  4379.000000
# mean   ...     0.245951     0.632336     0.374184     0.867601     0.451701
# std    ...     0.430699     0.482224     0.483999     0.338984     0.497719
# min    ...     0.000000     0.000000     0.000000     0.000000     0.000000
# 25%    ...     0.000000     0.000000     0.000000     1.000000     0.000000
# 50%    ...     0.000000     1.000000     0.000000     1.000000     0.000000
# 75%    ...     0.000000     1.000000     1.000000     1.000000     1.000000
# max    ...     1.000000     1.000000     1.000000     1.000000     1.000000
#
#          inpatient   numberbeds   total_full       LATNUM      LONGNUM
# count  4379.000000  2778.000000  4282.000000  4316.000000  4316.000000
# mean      0.412423    35.444204    24.924568    13.775843    20.145659
# std       0.492327    95.061828    73.792766    11.375674    63.026978
# min       0.000000     0.000000     0.000000   -12.742820   -74.454312
# 25%       0.000000     3.000000     3.000000     1.916200   -17.334832
# 50%       0.000000    10.000000     8.000000    18.551235    23.309045
# 75%       1.000000    38.000000    24.750000    22.965235    89.706431
# max       1.000000   998.000000  2573.000000    26.587388    92.429650
#
# [8 rows x 21 columns]

# %%
# Count sample size for each country
df['Country'].value_counts()
# Out:
# BAN    1600
# DRC    1412
# HAI    1033
# SEN     484
# Name: Country, dtype: int64

# %%
# Create preparedness dataframe for each country 
senegal = df.loc[lambda df: df['Country'] == 'SEN']
SEN = senegal['preparedness'].dropna()
bangladesh = df.loc[lambda df: df['Country'] == 'BAN']
BAN = bangladesh['preparedness'].dropna()
haiti = df.loc[lambda df: df['Country'] == 'HAI']
HAI = haiti['preparedness'].dropna()
congo = df.loc[lambda df: df['Country'] == 'DRC']
DRC = congo['preparedness'].dropna()

# %%
# Box plot for preparedness by Country 
x_labels = ["SEN", "BAN","HAI","DRC"]
preparedness_data = [SEN, BAN, HAI, DRC]
fig, ax = plt.subplots(figsize=(10, 6))
ax.boxplot(preparedness_data, labels=x_labels)
ax.set_title('Preparedness by Country')
ax.set_ylabel('Preparedness for infection control')
ax.grid()
plt.show()
